# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/sai/Desktop/nanis/housing.csv")

# %%
print(df.head(n=1))  
#prints only first record
# Out:
#    lotsize  bedrooms  bathrms  stories  driveway  recroom  fullbase  gashw  \
# 0     5850         3        1        2         1        0         1      0
#
#    airco  garagepl  prefarea  price
# 0      0         1         0  42000

# %%
print(df.head())
#prints first five records
# Out:
#    lotsize  bedrooms  bathrms  stories  driveway  recroom  fullbase  gashw  \
# 0     5850         3        1        2         1        0         1      0
# 1     4000         2        1        1         1        0         0      0
# 2     3060         3        1        1         1        0         0      0
# 3     6650         3        1        2         1        1         0      0
# 4     6360         2        1        1         1        0         0      0
#
#    airco  garagepl  prefarea  price
# 0      0         1         0  42000
# 1      0         0         0  38500
# 2      0         0         0  49500
# 3      0         0         0  60500
# 4      0         0         0  61000

# %%
print(df['lotsize'].mean())
#prints the total mean of lotsize column
# Out:
# 5150.2655677655675

# %%
print(df['bedrooms'].median())
#prints the median of bedrooms column
# Out:
# 3.0

# %%
print(df['lotsize'].std())
#prints the standard variation of lotsize column
# Out:
# 2168.1587252285567

# %%
print(df['bedrooms'].head(50).mean())
#prints mean of first fifty bedrooms columns
# Out:
# 2.72

# %%
df_sample=df.groupby(['lotsize'])
print(df_sample.mean())
#groups the data in the lotsize column
# Out:
#          bedrooms   bathrms   stories  driveway  recroom  fullbase  gashw  \
# lotsize
# 1650     3.000000  1.000000  2.000000       0.0     0.00  1.000000    0.0
# 1700     3.000000  1.000000  2.000000       1.0     0.00  0.000000    0.0
# 1836     2.000000  1.000000  1.000000       0.0     0.00  1.000000    0.0
# 1905     5.000000  1.000000  2.000000       0.0     0.00  1.000000    0.0
# 1950     3.000000  1.500000  1.500000       0.5     0.00  0.500000    0.5
# 2000     2.000000  1.000000  2.000000       1.0     0.00  0.000000    0.0
# 2015     3.000000  1.000000  2.000000       1.0     0.00  1.000000    0.0
# 2135     3.000000  2.000000  2.000000       0.0     0.00  0.000000    0.0
# 2145     3.166667  1.166667  2.333333       1.0     0.00  0.500000    0.0
# 2160     3.000000  1.000000  2.000000       0.0     0.00  1.000000    0.0
# 2175     3.000000  1.000000  2.000000       0.0     1.00  1.000000    0.0
# ...

# %%
df_sub=df[df['lotsize']>2500]
print(df_sub)
#data frame filtering-displays the records of lotsize column greater than 2500
# Out:
#      lotsize  bedrooms  bathrms  stories  driveway  recroom  fullbase  gashw  \
# 0       5850         3        1        2         1        0         1      0
# 1       4000         2        1        1         1        0         0      0
# 2       3060         3        1        1         1        0         0      0
# 3       6650         3        1        2         1        1         0      0
# 4       6360         2        1        1         1        0         0      0
# 5       4160         3        1        1         1        1         1      0
# 6       3880         3        2        2         1        0         1      0
# 7       4160         3        1        3         1        0         0      0
# 8       4800         3        1        1         1        1         1      0
# 9       5500         3        2        4         1        1         0      0
# 10      7200         3        2        1         1        0         1      0
# ...

# %%
df_sub=df[df['lotsize']>2500]
print(df_sub.loc[10:40,['lotsizes','bedrooms']])
#
# Out:
#     lotsizes  bedrooms
# 10       NaN         3
# 11       NaN         2
# 13       NaN         3
# 14       NaN         2
# 15       NaN         2
# 16       NaN         3
# 17       NaN         4
# 18       NaN         1
# 19       NaN         2
# 20       NaN         3
# 21       NaN         4
# 22       NaN         3
# 23       NaN         2
# 24       NaN         2
# 25       NaN         2
# 26       NaN         2
# 27       NaN         2
# 28       NaN         3
# 29       NaN         3
# 30       NaN         2
# 31       NaN         4
# 32       NaN         2
# 33       NaN         2
# 34       NaN         2
# 35       NaN         2
# 36       NaN         2
# 37       NaN         3
# 38       NaN         4
# 39       NaN         2
# 40       NaN         3
